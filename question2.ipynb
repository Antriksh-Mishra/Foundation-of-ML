# %% [markdown]
# Roll Numbers Ending With 4 or 5
#
# Domain: Finance & E-commerce
#
# Required Plots: Scatter (Income vs Spending), Histogram (Orders), Line plot (Spotify)
#
# Raw Data (IDs 1 to 20)
#
# Monthly_Income:
# 15000, 18000, 20000, 22000, 17000, 19000, 21000, 23000, 16000, 20000, 18000, 22000, 21000, 24000, 17000, 19000, 20000, 23000, 18000, 21000
#
# Online_Orders:
# 3, 4, 5, 6, 4, 5, 6, 7, 3, 5, 4, 6, 5, 7, 4, 5, 6, 7, 4, 5
#
# Spotify_Hrs:
# 1, 2, 3, 4, 2, 3, 4, 5, 1, 3, 2, 4, 3, 5, 2, 3, 4, 5, 2, 3
#
# Shop_Hours:
# 2, 3, 4, 5, 3, 4, 5, 6, 2, 4, 3, 5, 4, 6, 3, 4, 5, 6, 3, 4
#
# Money_Spent:
# 4000, 4500, 5000, 6000, 4200, 4800, 5500, 6500, 4100, 5000, 4600, 6000, 5300, 6800, 4300, 4900, 5200, 6700, 4500, 5400

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
income = [15000,18000,20000,22000,17000,19000,21000,23000,16000,20000,
          18000,22000,21000,24000,17000,19000,20000,23000,18000,21000]

orders = [3,4,5,6,4,5,6,7,3,5,4,6,5,7,4,5,6,7,4,5]

spotify = [1,2,3,4,2,3,4,5,1,3,2,4,3,5,2,3,4,5,2,3]

shop_hours = [2,3,4,5,3,4,5,6,2,4,3,5,4,6,3,4,5,6,3,4]

money_spent = [4000,4500,5000,6000,4200,4800,5500,6500,4100,5000,
               4600,6000,5300,6800,4300,4900,5200,6700,4500,5400]

# Convert to numpy arrays
income = np.array(income)
orders = np.array(orders)
spotify = np.array(spotify)
money_spent = np.array(money_spent)

# Statistics
print("Mean Income:", np.mean(income))
print("Median Income:", np.median(income))
print("Std Deviation Income:", np.std(income))

print("Mean Spending:", np.mean(money_spent))
print("Median Spending:", np.median(money_spent))
print("Std Deviation Spending:", np.std(money_spent))

# Correlation
correlation = np.corrcoef(income, money_spent)[0,1]
print("Correlation (Income vs Spending):", correlation)

# Scatter Plot
plt.scatter(income, money_spent)
plt.title("Income vs Money Spent")
plt.xlabel("Monthly Income")
plt.ylabel("Money Spent")
plt.show()

# Histogram
plt.hist(orders)
plt.title("Distribution of Online Orders")
plt.xlabel("Orders")
plt.ylabel("Frequency")
plt.show()

# Line Plot
plt.plot(spotify)
plt.title("Spotify Listening Hours")
plt.xlabel("User ID")
plt.ylabel("Hours")
plt.show()
# Out:
# Mean Income: 19700.0
# Median Income: 20000.0
# Std Deviation Income: 2410.39415863879
# Mean Spending: 5165.0
# Median Spending: 5000.0
# Std Deviation Spending: 837.4216381250249
# Correlation (Income vs Spending): 0.9707625709778246

# %% [markdown]
# The analysis shows a strong positive correlation between monthly income and money spent on shopping. This indicates that individuals with higher income tend to spend more. The histogram of online orders shows that most users place around 4–6 orders per month. The line plot of Spotify listening hours shows moderate variation in music listening habits across users. Overall, the data suggests that higher income users are more active in online shopping and digital entertainment.
